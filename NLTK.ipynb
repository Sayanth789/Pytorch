# %% [markdown]
# ## Tokenize text using NLTK in python
#
# Text tokenization is a fundamental Natural Language Processing (NLP) technique and one such technique is Tokenization. It is the process of dividing text into smaller components or tokens. These can be:
#
#     * Words: “I love NLP” → ["I", "love", "NLP"]
#     * Sentences: “I love NLP. Python is great.” → ["I love NLP.", "Python is great."]

# %%
# NLTK : Natural Language Toolkit) : Is Python's Library used to splitting the text into
# meaningful units .

# %% [markdown]
#  step 2: tokenizing the sentence

# %%
# !pip install nltk

import nltk
nltk.download('punkt')
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# this version also need to download this one:
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

text = "NLTK is a great NLP toolkit. It makes processing text easy!"
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['NLTK is a great NLP toolkit.', 'It makes processing text easy!']

# %% [markdown]
# 3 Tokenize the words()
#  * words_tokenize() splits a sentnece into words and punctuatins marks as seperate tokens.
#  * Handles contractions, punctuations , numbers, and more

# %%
from nltk.tokenize import word_tokenize

sentence = "Tokenization is easy with NLTK's word_tokenize."
words = word_tokenize(sentence)
print(words)
# Out:
# ['Tokenization', 'is', 'easy', 'with', 'NLTK', "'s", 'word_tokenize', '.']

# %% [markdown]
# # 1 WordPunctTokenizer
# It splits text into alphabets and non-alphabetic characters.
#
# * seperates all sequneces of word characters and punctuation in to tokens.
# *  Especially spluts contrcations  (Don't becomes Don,',t).
# * Splits E-mails ito E ,-, mails.

# %%
from  nltk.tokenize import WordPunctTokenizer

tokenizer = WordPunctTokenizer()
tokens  = tokenizer.tokenize(
    "Don't split contractions. E-Mails: hello@example.com!"
)

print(tokens)
# Out:
# ['Don', "'", 't', 'split', 'contractions', '.', 'E', '-', 'Mails', ':', 'hello', '@', 'example', '.', 'com', '!']

# %% [markdown]
# # TreebankWordTokenizer
#
# It is suitable for linguistic analysis, handles punctuations and contractions
# * Mimics Penn Treebank-style tokenization, which is commonly used for NLP linguistic
#
# * Handles certain English grammatical strutures more "intelligently"

# %%
from nltk.tokenize import TreebankWordDetokenizer

tokenizer = TreebankWordDetokenizer()
tokens  = tokenizer.tokenize("Have a look at NLTK's tokenizers.")

print(tokens)
# Out:
# H a v e   a   l o o k   a t   N L T K' s   t o k e n i z e r s.

# %% [markdown]
# # 3 Regex Tokenizer
#
# It Customize pattern-based splitting
#
# * Tokeizes based on a regular expressin pattern
# * \w+ matches words and numbers, omitting punctuation completely.

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize( "Custom rule: keep only words & numbers, drop punctuation!")
print(tokens)
# Out:
# ['Custom', 'rule', 'keep', 'only', 'words', 'numbers', 'drop', 'punctuation']
