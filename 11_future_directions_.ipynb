# %%
# !git clone https://github.com/nlp-with-transformers/notebooks.git
# %cd notebooks
from install import *
install_requirements(is_chapter11=True)
# Out:
# Cloning into 'notebooks'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 530 (delta 209), reused 186 (delta 186), pack-reused 288 (from 1)
# Receiving objects: 100% (530/530), 34.57 MiB | 20.14 MiB/s, done.
# Resolving deltas: 100% (249/249), done.
# /content/notebooks
# ⏳ Installing base requirements ...
# ✅ Base requirements installed!
# ⏳ Installing Git LFS ...
# ✅ Git LFS installed!
# ⏳ Installing torch-scatter for torch v2.8.0 ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3014020658.py in <cell line: 0>()
#       2 get_ipython().run_line_magic('cd', 'notebooks')
#       3 from install import *
# ----> 4 install_requirements(is_chapter11=True)
#
# /content/notebooks/install.py in install_requirements(is_chapter2, is_chapter6, is_chapter7, is_chapter7_v2, is_chapter10, is_chapter11)
#      68         print(f"⏳ Installing torch-scatter for torch v{torch_version} ...")
#      69         if is_colab:
# ---> 70             torch_scatter_cmd = f"python -m pip install torch-scatter -f https://data.pyg.org/whl/torch-{torch_version}+{torch_to_cuda[torch_version]}.html".split()
#      71         else:
#      72             # Kaggle uses CUDA 11.0 by default, so we need to build from source
#
# KeyError: '2.8.0'

# %%
from utils import *
setup_chapter()

# %% [markdown]
# #Future Directions
# ###Scaling Transformers

# %%
model_data = [
    {'date': '12-06-2017', 'name': 'Transformers', 'size': 213*1e6},
    ['date': '11-06-2018', 'name': 'GPT', 'size': 110*1e6],
    {'date': '11-10-2018', 'name': 'BERT', 'size': 340*1e6},
    {'date': '14-02-2019', 'name': 'GPT-2', 'size': 1.5*1e9},
    {'date': '23-10-2019', 'name': 'T5', 'size': 11*1e9},
    {'date': '17-09-2019', 'name': 'Megatron', 'size': 8.3*1e9},
    {'date': '13-02-2020', 'name': 'Turing-NLG', 'size': 17*1e9},
    {'date': '30-06-2020', 'name': 'GShard', 'size': 600*1e9},
    {'date': '28-05-2020', 'name': 'GPT-3', 'size': 175*1e9},
    {'date': '11-01-2021', 'name': 'Switch-C', 'size': 1.571*10e12},

]

# %%
# id parameters-counts
# alt language model parameter counts
# caption parameter counts over time for prominent Transformer architecture
import pandas as pd
import matplotlib.pyplot as plt


def label_point(x, y, val, ax):
  a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
  for i , point in a.iterrows():
    ax.text(
        point['x'],
        point['y'],
        str(point['val']),
        horizontalalignment='center',
        verticalalignment='bottom'
    )

df_lm = pd.DataFrame.from_records(model_data)
df_lm['data'] = pd.to_datetime(df_lm['data'], dayfirst=True)

fig, ax = plt.subplots(1, 1, figsize=(12, 4))
df_lm.plot(x='date', y='size', kind='scatter', s=15, ax=ax)
ax.set_yscale(df_lm['date'], df_lm['size'], df_lm['name'], ax)
ax.set_xlabel("Release date")
ax.set_ylabel("Number of parameters")
ax.grid(True)
plt.subplots_adjust(top=1.2)
plt.show()

# %% [markdown]
# #Going Beyond Text
#
# ##Vision

# %%
from PIL import Image
import matplotlib.pyplot as plt


image = Image.open("images/doge.jpg")
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import pandas as pd
from transformers import pipeline

image_classifier = pipeline('image-classification')
preds = image_classifier(image)
preds_df = pd.DataFrame(preds)
preds_df

# %%
book_data = [
    {"chapter": 0, "name": "Introduction", "start_page": 1, "end_page": 11},
    {"chapter": 1, "name": "Text classification", "start_page": 12,
     "end_page": 48},
    {"chapter": 2, "name": "Named Entity Recognition", "start_page": 49,
     "end_page": 73},
    {"chapter": 3, "name": "Question Answering", "start_page": 74,
     "end_page": 120},
    {"chapter": 4, "name": "Summarization", "start_page": 121,
     "end_page": 140},
    {"chapter": 5, "name": "Conclusion", "start_page": 141,
     "end_page": 144}
]

# %%
table = pd.DataFrmae(book_data)
label['number_of_pages'] = table['end_page']-table['start_page']
table = table.astype(str)
table

# %%
table_qa = pipeline('table-question-answering')

# %%
table_qa = pipeline("table-question-answering")
queries = ["What's the topic in chapter 4?",
           "What is the total number of pages?",
           "On which page does the chapter about question-answering start?",
           "How many chapters have more than 20 pages?"]
preds = table_qa(table, queries)

# %%
for query, pred in zip(queries, preds):
  print(query)
  if pred['aggregator'] == 'NONE':
    print("Predicted answer: " + pred["answer"])
  else:
    print("predicted answer: " + pred['answer'])
  print('='*50)

# %% [markdown]
# #Multimodal Transformers

# %%
asr = pipeline("automatic-speech-recognition")

# %%
from datasets import load_dataset

ds = load_dataset("superb", "asr", split="validation[:1]")
print(ds[0])

# %%
import soundfile as f

def map_to_array(batch):
  speech, _ = sf.read(batch['file'])
  batch['speech'] = speech
  return batch

ds = ds.map(map_to_array)

# %%
from IPython.display import Auto

display(Audio(ds[0]['speech'], rate=16000))

# %%
ds.set_format("numpy")

# %%
pred = asr(ds[0]['speech'])
print(pred)

# %%
from transformers import CLIPProcessor, CLIPModel

clip_ckpt =  "openai/clip-vit-base-patch32"
model = CLIPModel.from_pretrained(clip_ckpt)
processor = CLIPProcessor.from_pretrained(clip_ckpt)

# %%
image = Image.open("images/optimusprime.jpg")
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import torch

texts = ["a photo of a transformer ", "a photo of a robot", "a photo of agi"]
inputs = processor(text=texts, images=image, return_tensors='pt', padding=True)
with torch.no_grad():
  outputs = model(**inputs)
logits_per_image = outputs.logits_per_image
probs = logints_per_image.softmax(dim=1)
probs
